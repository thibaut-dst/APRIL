# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from googlesearch import search
import os

# Charger les mots-clés du CSV
file_path = 'cleaned_keywords.csv'
keywords_df = pd.read_csv(file_path)

# Créer un dossier pour sauvegarder les fichiers HTML
os.makedirs("html_pages", exist_ok=True)

# Fonction pour vérifier la présence de mots-clés dans le contenu HTML
def contains_keywords(content, keyword):
    return keyword.lower() in content.lower()

# Fonction de recherche Google et scraping
def scrape_webpages(keywords_df):
    for index, row in keywords_df.iterrows():
        # Extraire les mots-clés séparés par des virgules
        keywords = [kw.strip() for kw in row['Keywords'].split(',')]
        
        # Pour chaque mot-clé individuel
        for keyword in keywords:
            print(f"Recherche Google effectuée avec : {keyword}")  # Afficher la recherche Google

            # Utiliser le mot-clé pour effectuer une recherche Google (max 5 résultats par recherche)
            for url in search(keyword):
                try:
                    # Faire la requête HTTP pour récupérer la page HTML
                    response = requests.get(url)
                    response.raise_for_status()
                    
                    # Analyser le contenu HTML
                    soup = BeautifulSoup(response.text, 'html.parser')
                    content = soup.get_text()
                    
                    # Vérifier si le mot-clé est présent dans la page
                    if contains_keywords(content, keyword):
                        # Sauvegarder la page HTML si elle contient le mot-clé
                        file_name = f"html_pages/page_{index}_{keyword.replace(' ', '_')}.html"
                        with open(file_name, 'w', encoding='utf-8') as file:
                            file.write(response.text)
                        print(f"Page HTML sauvegardée : {file_name}")
                    else:
                        print(f"Aucun mot-clé trouvé dans la page {url}")
                except requests.exceptions.RequestException as e:
                    print(f"Erreur lors de l'accès à la page {url}: {e}")

# Lancer le processus de scraping
scrape_webpages(keywords_df)
# Out:
# Recherche Google effectuée avec : Aléas générés par le changement climatique
# Aucun mot-clé trouvé dans la page https://www.inspq.qc.ca/sites/default/files/publications/2771-aleas-changements-climatiques-effets-sante-vulnerabilite-adaptation.pdf
# Aucun mot-clé trouvé dans la page https://www.irsn.fr/savoir-comprendre/surete/risques-lies-aleas-climatiques
# Aucun mot-clé trouvé dans la page https://climat.cned.fr/formations/consequences-et-adaptation/
# Aucun mot-clé trouvé dans la page https://www.inspq.qc.ca/publications/2771
# Aucun mot-clé trouvé dans la page https://www.arec-idf.fr/fileadmin/DataStorageKit/AREC/Etudes/pdf/Adaptation_au_changement_climatique_et_Plan_climat_-_1.pdf
# Aucun mot-clé trouvé dans la page https://www.senat.fr/rap/r18-628/r18-6282.html
# Aucun mot-clé trouvé dans la page https://www.notre-environnement.gouv.fr/themes/climat/comprendre-le-changement-climatique-ressources/article/risques-climatiques-six-francais-sur-dix-sont-d-ores-et-deja-concernes
# Aucun mot-clé trouvé dans la page https://theshiftproject.org/article/climat-effets-adaptation-6eme-rapport-giec/
# Erreur lors de l'accès à la page https://www.economie.gouv.fr/actualites/rapport-mieux-assurer-francais-changement-climatique: 403 Client Error: Forbidden for url: https://www.economie.gouv.fr/actualites/rapport-mieux-assurer-francais-changement-climatique
# Aucun mot-clé trouvé dans la page https://www.adaptation-changement-climatique.gouv.fr/comprendre/decryptage/eclairages/aleas-risques-mal-adaptation-quoi-parle-t-exactement
# Recherche Google effectuée avec : Spécificités des territoires littoraux
# Aucun mot-clé trouvé dans la page https://www.ecologie.gouv.fr/politiques-publiques/adaptation-territoires-aux-evolutions-du-littoral
# Aucun mot-clé trouvé dans la page https://www.statistiques.developpement-durable.gouv.fr/edition-numerique/chiffres-cles-mer-littoral-2024/pdf/pages/partie1/partie1.pdf
# Aucun mot-clé trouvé dans la page https://geoconfluences.ens-lyon.fr/glossaire/littoral
# Aucun mot-clé trouvé dans la page https://www.giplittoral.fr/ressources/etude-sur-la-capacite-daccueil-des-territoires-littoraux
# Erreur lors de l'accès à la page https://www.age-platform.eu/vieillissement-et-territoires-littoraux-10-enjeux-a-lere-du-changement-climatique/: 403 Client Error: Forbidden for url: https://www.age-platform.eu/vieillissement-et-territoires-littoraux-10-enjeux-a-lere-du-changement-climatique/
# Erreur lors de l'accès à la page https://theshiftproject.org/wp-content/uploads/2022/10/TSP_SRT_Cahiers_LITTORAL_WEB.pdf: ('Connection broken: IncompleteRead(13564544 bytes read, 3381708 more expected)', IncompleteRead(13564544 bytes read, 3381708 more expected))
# Aucun mot-clé trouvé dans la page https://www.ecologie.gouv.fr/politiques-publiques/specificites-damenagement-du-littoral-instructions-elus
# Aucun mot-clé trouvé dans la page https://www.mer.gouv.fr/adaptation-des-territoires-aux-evolutions-du-littoral
# Aucun mot-clé trouvé dans la page https://www.vie-publique.fr/eclairage/288586-protection-du-littoral-quelle-strategie-face-aux-risques-climatiques
# Aucun mot-clé trouvé dans la page https://www.aurh.fr/observatoires-et-etudes/loi-littoral
# Recherche Google effectuée avec : Méthodes traditionnelles de gestion des risques côtiers
# Aucun mot-clé trouvé dans la page https://www.cerema.fr/system/files/documents/2023/12/guide_de_la_gestion_des_risques_littoraux_volet_2_print_1.pdf
# Aucun mot-clé trouvé dans la page https://pole-lagunes.org/quelle-methodologie-adopter-pour-une-meilleure-gestion-des-risques-derosion-et-de-submersion-marine/
# Aucun mot-clé trouvé dans la page https://hal.science/hal-00430767/document
# Aucun mot-clé trouvé dans la page https://journals.openedition.org/vertigo/10215
# Erreur lors de l'accès à la page https://www.risques-cotiers.fr/wp-content/uploads/2021/02/guide-cocorisco-final-dec2014-risques-cotiers.pdf: HTTPSConnectionPool(host='www.risques-cotiers.fr', port=443): Max retries exceeded with url: /wp-content/uploads/2021/02/guide-cocorisco-final-dec2014-risques-cotiers.pdf (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)')))
# Aucun mot-clé trouvé dans la page https://www.finistere.fr/wp-content/uploads/2023/11/Guide_de_la_gestion_des_risques_littoraux_Volet_3_light.pdf
# Erreur lors de l'accès à la page https://www.risques-cotiers.fr/connaitre-les-risques-cotiers/connaitre-les-representations/: HTTPSConnectionPool(host='www.risques-cotiers.fr', port=443): Max retries exceeded with url: /connaitre-les-risques-cotiers/connaitre-les-representations/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)')))
# Aucun mot-clé trouvé dans la page https://pole-lagunes.org/guide-methodologique-gestion-des-risques-derosion-et-de-submersion-marines/
# Aucun mot-clé trouvé dans la page https://www.ecologie.gouv.fr/sites/default/files/documents/Guide_m%C3%A9thodo_PPRL_%202014.pdf
# Aucun mot-clé trouvé dans la page https://gestion-risques.solutions/solution-gestion-risques-cotiers/
# Recherche Google effectuée avec : Politiques de transition
# Aucun mot-clé trouvé dans la page https://www.ecologie.gouv.fr/nos-actions
# Aucun mot-clé trouvé dans la page https://reform-support.ec.europa.eu/what-we-do/green-transition_fr
# Aucun mot-clé trouvé dans la page https://irev.fr/thematiques/transition
# Erreur lors de l'accès à la page https://www.economie.gouv.fr/economie-verte/piloter-la-transition-ecologique-de-leconomie: 403 Client Error: Forbidden for url: https://www.economie.gouv.fr/economie-verte/piloter-la-transition-ecologique-de-leconomie
# Aucun mot-clé trouvé dans la page https://www.info.gouv.fr/politiques-prioritaires/planifier-et-accelerer-la-transition-ecologique
# Aucun mot-clé trouvé dans la page https://www.ecologie.gouv.fr/actualites/transition-ecologique-ce-qui-change-1er-janvier-2024
# Aucun mot-clé trouvé dans la page https://www.caissedesdepots.fr/blog/article/inventer-de-nouvelles-politiques-publiques-de-transition
# Aucun mot-clé trouvé dans la page https://www.sciencespo.fr/cso/fr/actualites/les-transitions-sociales-ecologiques-analyses-et-politiques.html
# Page HTML sauvegardée : html_pages/page_0_Politiques_de_transition.html
# Aucun mot-clé trouvé dans la page https://www.ehess.fr/fr/d%C3%A9bat/moyens-politiques-r%C3%A9ussir-transition-%C3%A9cologique
# Recherche Google effectuée avec : Territoires concernés
# Page HTML sauvegardée : html_pages/page_0_Territoires_concernés.html
# Page HTML sauvegardée : html_pages/page_0_Territoires_concernés.html
# Aucun mot-clé trouvé dans la page https://www.tzcld.fr/decouvrir-le-projet/les-territoires/
# Aucun mot-clé trouvé dans la page https://agence-cohesion-territoires.gouv.fr/action-coeur-de-ville-42
# Aucun mot-clé trouvé dans la page https://www.data.gouv.fr/fr/datasets/liste-des-territoires-dindustrie-et-des-communes-concernees/
# Page HTML sauvegardée : html_pages/page_0_Territoires_concernés.html
# Page HTML sauvegardée : html_pages/page_0_Territoires_concernés.html
# Page HTML sauvegardée : html_pages/page_0_Territoires_concernés.html
# Aucun mot-clé trouvé dans la page https://taxation-customs.ec.europa.eu/territorial-status-eu-countries-and-certain-territories_fr
# Page HTML sauvegardée : html_pages/page_0_Territoires_concernés.html
# Recherche Google effectuée avec : Institutions et acteurs
# Aucun mot-clé trouvé dans la page https://www.strategie-aims.com/community/prices/4/theses/36/thesis_assets/31/download
# Page HTML sauvegardée : html_pages/page_0_Institutions_et_acteurs.html
# Page HTML sauvegardée : html_pages/page_0_Institutions_et_acteurs.html
# Page HTML sauvegardée : html_pages/page_0_Institutions_et_acteurs.html
# Page HTML sauvegardée : html_pages/page_0_Institutions_et_acteurs.html
# Page HTML sauvegardée : html_pages/page_0_Institutions_et_acteurs.html
# Page HTML sauvegardée : html_pages/page_0_Institutions_et_acteurs.html
# Erreur lors de l'accès à la page https://www.amazon.fr/Institutions-acteurs-laction-sociale-%C3%A9dition/dp/2216128260: 503 Server Error: Service Unavailable for url: https://www.amazon.fr/Institutions-acteurs-laction-sociale-%C3%A9dition/dp/2216128260
# Aucun mot-clé trouvé dans la page https://hal.science/hal-01494927
# Erreur lors de l'accès à la page https://www.fnac.com/a12230964/Vincent-Chevreux-Le-Volum-BTS-Action-sanitaire-et-sociale-institutions-et-acteurs-6e-edition-Revision: 403 Client Error: Forbidden for url: https://www.fnac.com/a12230964/Vincent-Chevreux-Le-Volum-BTS-Action-sanitaire-et-sociale-institutions-et-acteurs-6e-edition-Revision
# Recherche Google effectuée avec : Submersion marine
# Page HTML sauvegardée : html_pages/page_1_Submersion_marine.html
# Page HTML sauvegardée : html_pages/page_1_Submersion_marine.html
# Page HTML sauvegardée : html_pages/page_1_Submersion_marine.html
# Page HTML sauvegardée : html_pages/page_1_Submersion_marine.html
# Page HTML sauvegardée : html_pages/page_1_Submersion_marine.html
# Erreur lors de l'accès à la page https://www.nord.gouv.fr/Actions-de-l-Etat/Prevention-des-risques-naturels-technologiques-et-miniers/Typologie-des-risques-dans-le-Nord/La-submersion-marine: 410 Client Error: Gone for url: https://www.nord.gouv.fr/Actions-de-l-Etat/Prevention-des-risques-naturels-technologiques-et-miniers/Typologie-des-risques-dans-le-Nord/La-submersion-marine
# Page HTML sauvegardée : html_pages/page_1_Submersion_marine.html
# Erreur lors de l'accès à la page https://www.var.gouv.fr/Actions-de-l-Etat/Risques-naturels-et-technologiques/Inondation/Submersion-marine/Le-porter-a-connaissance-de-l-alea-submersion-marine: 410 Client Error: Gone for url: https://www.var.gouv.fr/Actions-de-l-Etat/Risques-naturels-et-technologiques/Inondation/Submersion-marine/Le-porter-a-connaissance-de-l-alea-submersion-marine
# Erreur lors de l'accès à la page https://www.pas-de-calais.gouv.fr/Politiques-publiques/Prevention-des-risques-majeurs/Connaissance-des-risques-dans-le-P-d-C/Les-risques-naturels/Le-risque-littoral/La-submersion-marine: 410 Client Error: Gone for url: https://www.pas-de-calais.gouv.fr/Politiques-publiques/Prevention-des-risques-majeurs/Connaissance-des-risques-dans-le-P-d-C/Les-risques-naturels/Le-risque-littoral/La-submersion-marine
# Page HTML sauvegardée : html_pages/page_1_Submersion_marine.html
# Recherche Google effectuée avec : Inondation côtière
# Erreur lors de l'accès à la page https://www.aquaportail.com/dictionnaire/definition/3535/inondation-cotiere: 403 Client Error: Forbidden for url: https://www.aquaportail.com/dictionnaire/definition/3535/inondation-cotiere
# Aucun mot-clé trouvé dans la page https://www.georisques.gouv.fr/articles-risques/inondations/les-inondations-par-submersion-marine
# Aucun mot-clé trouvé dans la page https://www.c40.org/fr/what-we-do/scaling-up-climate-action/adaptation-water/the-future-we-dont-want/sea-level-rise/
# Page HTML sauvegardée : html_pages/page_1_Inondation_côtière.html
# Aucun mot-clé trouvé dans la page http://www.vedura.fr/environnement/eau/inondations-zones-cotieres-montee-niveau-mers
# Page HTML sauvegardée : html_pages/page_1_Inondation_côtière.html
# Erreur lors de l'accès à la page https://www2.gnb.ca/content/gnb/fr/ministeres/egl/environnement/content/inondations/inondations_cotieres_etondesdetempete.html: 403 Client Error: Forbidden for url: https://www2.gnb.ca/content/gnb/fr/ministeres/egl/environnement/content/inondations/inondations_cotieres_etondesdetempete.html
# Erreur lors de l'accès à la page https://shs.cairn.info/revue-juridique-de-l-environnement-2012-5-page-155?lang=fr: 403 Client Error: Forbidden for url: https://shs.cairn.info/revue-juridique-de-l-environnement-2012-5-page-155?lang=fr
# Aucun mot-clé trouvé dans la page https://www.appcb.fr/wp-content/uploads/2021/01/fiche_thematique_inondation.pdf
# Aucun mot-clé trouvé dans la page https://oceandecade.org/fr/news/flood-risk-strengthening-resilience-of-coastal-communities-through-improved-forecasting-and-projection/
# Recherche Google effectuée avec : Lagunes
# Page HTML sauvegardée : html_pages/page_1_Lagunes.html
# Aucun mot-clé trouvé dans la page https://www.larousse.fr/dictionnaires/francais/lagune/45922
# Page HTML sauvegardée : html_pages/page_1_Lagunes.html
# Page HTML sauvegardée : html_pages/page_1_Lagunes.html
# Aucun mot-clé trouvé dans la page https://geoconfluences.ens-lyon.fr/glossaire/lagune
# Erreur lors de l'accès à la page https://www.parc-naturel-narbonnaise.fr/decouvrir/sites-a-decouvrir/le-littoral/lagunes-et-marais: 403 Client Error: Forbidden for url: https://www.parc-naturel-narbonnaise.fr/decouvrir/sites-a-decouvrir/le-littoral/lagunes-et-marais
# Page HTML sauvegardée : html_pages/page_1_Lagunes.html
# Page HTML sauvegardée : html_pages/page_1_Lagunes.html
# Aucun mot-clé trouvé dans la page https://geoconfluences.ens-lyon.fr/glossaire/lagune
# Recherche Google effectuée avec : Marais salants
# Page HTML sauvegardée : html_pages/page_1_Marais_salants.html
# Aucun mot-clé trouvé dans la page https://www.marais-salant.com/
# Page HTML sauvegardée : html_pages/page_1_Marais_salants.html
# Page HTML sauvegardée : html_pages/page_1_Marais_salants.html
# Erreur lors de l'accès à la page https://www.ville-guerande.fr/pratique-vos-demarches/tourisme-et-decouvertes/visiter-les-marais-salants: 403 Client Error: Forbidden for url: https://www.ville-guerande.fr/pratique-vos-demarches/tourisme-et-decouvertes/visiter-les-marais-salants
# Recherche Google effectuée avec : Epis
# Aucun mot-clé trouvé dans la page https://www.larousse.fr/dictionnaires/francais/%C3%A9pi/30324
# Page HTML sauvegardée : html_pages/page_1_Epis.html
# Page HTML sauvegardée : html_pages/page_1_Epis.html
# Aucun mot-clé trouvé dans la page https://www.vetementpro.com/content/51-definition-epi
# Aucun mot-clé trouvé dans la page https://fr.wikipedia.org/wiki/%C3%89pi_(maritime)
# Aucun mot-clé trouvé dans la page https://fr.wiktionary.org/wiki/%C3%A9pi
# Page HTML sauvegardée : html_pages/page_1_Epis.html
# Aucun mot-clé trouvé dans la page https://www.monepi.fr/
# Aucun mot-clé trouvé dans la page https://sept-epis.ent27.fr/
# Aucun mot-clé trouvé dans la page https://www.soscuisine.fr/recette/epis-mais
# Recherche Google effectuée avec : Brisants
# Page HTML sauvegardée : html_pages/page_1_Brisants.html
# Page HTML sauvegardée : html_pages/page_1_Brisants.html
# Page HTML sauvegardée : html_pages/page_1_Brisants.html
# Aucun mot-clé trouvé dans la page https://www.cnrtl.fr/definition/brisant
# Page HTML sauvegardée : html_pages/page_1_Brisants.html
# Erreur lors de l'accès à la page https://dictionnaire.lerobert.com/definition/brisant: 403 Client Error: Forbidden for url: https://dictionnaire.lerobert.com/definition/brisant
# Page HTML sauvegardée : html_pages/page_1_Brisants.html
# Page HTML sauvegardée : html_pages/page_1_Brisants.html
# Erreur lors de l'accès à la page https://dictionnaire.lerobert.com/en/definition/brisants: 403 Client Error: Forbidden for url: https://dictionnaire.lerobert.com/en/definition/brisants
# Erreur lors de l'accès à la page https://dictionnaire.lerobert.com/en/definition/brisants: 403 Client Error: Forbidden for url: https://dictionnaire.lerobert.com/en/definition/brisants
# Recherche Google effectuée avec : Relocalisation
# Page HTML sauvegardée : html_pages/page_1_Relocalisation.html
# Page HTML sauvegardée : html_pages/page_1_Relocalisation.html
# Page HTML sauvegardée : html_pages/page_1_Relocalisation.html
# Page HTML sauvegardée : html_pages/page_1_Relocalisation.html
# Page HTML sauvegardée : html_pages/page_1_Relocalisation.html
# Page HTML sauvegardée : html_pages/page_1_Relocalisation.html
# Aucun mot-clé trouvé dans la page https://www.vie-publique.fr/en-bref/291629-delocalisation-ou-relocalisation-de-lindustrie-evaluation-des-impacts
# Erreur lors de l'accès à la page https://www.cci.fr/actualites/enquete-relocalisation-2023: 403 Client Error: Forbidden for url: https://www.cci.fr/actualites/enquete-relocalisation-2023
# Erreur lors de l'accès à la page https://www.toupie.org/Dictionnaire/Relocalisation.htm: HTTPSConnectionPool(host='www.toupie.org', port=443): Max retries exceeded with url: /Dictionnaire/Relocalisation.htm (Caused by SSLError(SSLError(1, '[SSL: DH_KEY_TOO_SMALL] dh key too small (_ssl.c:1000)')))
# Page HTML sauvegardée : html_pages/page_1_Relocalisation.html
# Recherche Google effectuée avec : Déplacement des populations
# Page HTML sauvegardée : html_pages/page_1_Déplacement_des_populations.html
# Aucun mot-clé trouvé dans la page https://dictionnaire-droit-humanitaire.org/content/article/2/deplacement-de-population/
# Aucun mot-clé trouvé dans la page https://www.urd.org/fr/thematique/deplacement-de-populations/
# Erreur lors de l'accès à la page https://www.unhcr.org/fr/actualites/news-releases/les-chiffres-du-deplacement-force-dans-le-monde-atteignent-un-nouveau: 403 Client Error: Forbidden for url: https://www.unhcr.org/fr/actualites/news-releases/les-chiffres-du-deplacement-force-dans-le-monde-atteignent-un-nouveau
# Erreur lors de l'accès à la page https://www.nato.int/acad/fellow/99-01/munuma.pdf: 403 Client Error: Forbidden for url: https://www.nato.int/acad/fellow/99-01/munuma.pdf
# Aucun mot-clé trouvé dans la page https://fr.wikipedia.org/wiki/D%C3%A9placement_de_population_provoqu%C3%A9_par_le_d%C3%A9veloppement
# Erreur lors de l'accès à la page https://www.unhcr.org/fr/actualites/stories/des-deplacements-de-populations-sans-precedent-travers-le-monde: 403 Client Error: Forbidden for url: https://www.unhcr.org/fr/actualites/stories/des-deplacements-de-populations-sans-precedent-travers-le-monde
# Erreur lors de l'accès à la page https://www.ohchr.org/fr/housing/displacement: 403 Client Error: Forbidden for url: https://www.ohchr.org/fr/housing/displacement
# Aucun mot-clé trouvé dans la page https://occah.uqam.ca/populations-refugiees/
# Aucun mot-clé trouvé dans la page https://reliefweb.int/report/world/comment-le-changement-climatique-exacerbe-les-deplacements-de-population
# Recherche Google effectuée avec : Etablissements Publics Intercommunaux (EPCI)
# Aucun mot-clé trouvé dans la page https://www.vie-publique.fr/fiches/20118-la-cooperation-intercommunale-et-les-epci
# Aucun mot-clé trouvé dans la page https://www.collectivites-locales.gouv.fr/institutions/liste-et-composition-des-epci-fiscalite-propre
# Aucun mot-clé trouvé dans la page https://geoconfluences.ens-lyon.fr/glossaire/epci
# Aucun mot-clé trouvé dans la page https://fr.wikipedia.org/wiki/%C3%89tablissement_public_de_coop%C3%A9ration_intercommunale
# Aucun mot-clé trouvé dans la page https://www.collectivites-locales.gouv.fr/institutions/cartographie-des-epci-fiscalite-propre
# Aucun mot-clé trouvé dans la page https://www.legifrance.gouv.fr/affichCode.do?idSectionTA=LEGISCTA000006149301&cidTexte=LEGITEXT000006070633&dateTexte=20200512
# Aucun mot-clé trouvé dans la page https://www.insee.fr/fr/information/2510634
# Aucun mot-clé trouvé dans la page https://www.vie-publique.fr/fiches/270602-en-quoi-consiste-lintercommunalite
# Aucun mot-clé trouvé dans la page https://www.cdg35.fr/accueil_internet/rechercher_un_emploi/travailler_pour_le_service_public_local/les_differentes_collectivites_locales_et_leurs_attributions
# Aucun mot-clé trouvé dans la page https://mobile.interieur.gouv.fr/Archives/Archives-sous-sites/Reforme-des-collectivites-territoriales/La-reforme/Definition-des-termes-usuels
# Recherche Google effectuée avec : Communautés de communes
# Aucun mot-clé trouvé dans la page https://www.vie-publique.fr/fiches/20125-quest-ce-quune-communaute-de-communes
# Page HTML sauvegardée : html_pages/page_1_Communautés_de_communes.html
# Page HTML sauvegardée : html_pages/page_1_Communautés_de_communes.html
# Page HTML sauvegardée : html_pages/page_1_Communautés_de_communes.html
# Page HTML sauvegardée : html_pages/page_1_Communautés_de_communes.html
# Page HTML sauvegardée : html_pages/page_1_Communautés_de_communes.html
# Aucun mot-clé trouvé dans la page https://lannuaire.service-public.fr/navigation/epci
# Page HTML sauvegardée : html_pages/page_1_Communautés_de_communes.html
# Erreur lors de l'accès à la page https://www.intercommunalites.fr/lintercommunalite/reperes/: 403 Client Error: Forbidden for url: https://www.intercommunalites.fr/lintercommunalite/reperes/
# Page HTML sauvegardée : html_pages/page_1_Communautés_de_communes.html
# Recherche Google effectuée avec : DREAL
# Page HTML sauvegardée : html_pages/page_1_DREAL.html
# Page HTML sauvegardée : html_pages/page_1_DREAL.html
# Page HTML sauvegardée : html_pages/page_1_DREAL.html
# Page HTML sauvegardée : html_pages/page_1_DREAL.html
# Page HTML sauvegardée : html_pages/page_1_DREAL.html
# Page HTML sauvegardée : html_pages/page_1_DREAL.html
# Erreur lors de l'accès à la page https://immobilier-etat.gouv.fr/pages/directions-regionales-lenvironnement-lamenagement-logement-dreal: HTTPSConnectionPool(host='immobilier-etat.gouv.fr', port=443): Max retries exceeded with url: /pages/directions-regionales-lenvironnement-lamenagement-logement-dreal (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)')))
# Erreur lors de l'accès à la page https://www.nord.gouv.fr/Services-de-l-Etat/Presentation-des-services-de-l-Etat/Services-departementaux-de-l-Etat/Unite-departementale-Nord-de-la-Direction-regionale-environnement-amenagement-et-logement-DREAL: 410 Client Error: Gone for url: https://www.nord.gouv.fr/Services-de-l-Etat/Presentation-des-services-de-l-Etat/Services-departementaux-de-l-Etat/Unite-departementale-Nord-de-la-Direction-regionale-environnement-amenagement-et-logement-DREAL
# Page HTML sauvegardée : html_pages/page_1_DREAL.html
# Page HTML sauvegardée : html_pages/page_1_DREAL.html
# Recherche Google effectuée avec : Direction de l'Environnement
# Page HTML sauvegardée : html_pages/page_1_Direction_de_l'Environnement.html
# Page HTML sauvegardée : html_pages/page_1_Direction_de_l'Environnement.html
# Page HTML sauvegardée : html_pages/page_1_Direction_de_l'Environnement.html
# Aucun mot-clé trouvé dans la page https://www.hauts-de-france.developpement-durable.gouv.fr/
# Aucun mot-clé trouvé dans la page https://lannuaire.service-public.fr/navigation/dreal
# Aucun mot-clé trouvé dans la page https://www.ecologie.gouv.fr/services-deconcentres-du-ministere
# Page HTML sauvegardée : html_pages/page_1_Direction_de_l'Environnement.html
# Aucun mot-clé trouvé dans la page https://www.normandie.developpement-durable.gouv.fr/
# Page HTML sauvegardée : html_pages/page_1_Direction_de_l'Environnement.html
# Erreur lors de l'accès à la page https://www.actu-environnement.com/ae/dictionnaire_environnement/definition/direction_regionale_de_l_environnement_diren.php4: 403 Client Error: Forbidden for url: https://www.actu-environnement.com/ae/dictionnaire_environnement/definition/direction_regionale_de_l_environnement_diren.php4
# Recherche Google effectuée avec : de l'Aménagement et du Logement
# Page HTML sauvegardée : html_pages/page_1_de_l'Aménagement_et_du_Logement.html
# Aucun mot-clé trouvé dans la page https://www.ecologie.gouv.fr/direction-generale-lamenagement-du-logement-et-nature-dgaln-0
# Erreur lors de l'accès à la page https://immobilier-etat.gouv.fr/pages/directions-regionales-lenvironnement-lamenagement-logement-dreal: HTTPSConnectionPool(host='immobilier-etat.gouv.fr', port=443): Max retries exceeded with url: /pages/directions-regionales-lenvironnement-lamenagement-logement-dreal (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)')))
# Page HTML sauvegardée : html_pages/page_1_de_l'Aménagement_et_du_Logement.html
# Aucun mot-clé trouvé dans la page https://www.novethic.fr/lexique/detail/direction-regionale-de-l-environnement-de-l-amenagement-et-du-logement-dreal.html
# Page HTML sauvegardée : html_pages/page_1_de_l'Aménagement_et_du_Logement.html
# Erreur lors de l'accès à la page https://www.prefectures-regions.gouv.fr/hauts-de-france/Region-et-institutions/L-action-de-l-Etat-dans-la-region/Amenagement-du-territoire-logement-transport-et-infrastructures: 410 Client Error: Gone for url: https://www.prefectures-regions.gouv.fr/hauts-de-france/Region-et-institutions/L-action-de-l-Etat-dans-la-region/Amenagement-du-territoire-logement-transport-et-infrastructures
# Aucun mot-clé trouvé dans la page https://www.hauts-de-france.developpement-durable.gouv.fr/
# Aucun mot-clé trouvé dans la page https://aides-territoires.beta.gouv.fr/partenaires/411-direction-regionale-de-lenvironnement-de-lamenagem/
# Aucun mot-clé trouvé dans la page https://faq.hellio.com/definition-dreal
# Recherche Google effectuée avec : Montée des eaux
# Page HTML sauvegardée : html_pages/page_2_Montée_des_eaux.html
# Page HTML sauvegardée : html_pages/page_2_Montée_des_eaux.html
# Aucun mot-clé trouvé dans la page https://fr.oceancampus.eu/files/ressources/_text_file/O37.pdf
# Erreur lors de l'accès à la page https://www.worldvision.fr/climat-montee-des-eaux/: 403 Client Error: Forbidden for url: https://www.worldvision.fr/climat-montee-des-eaux/
# Aucun mot-clé trouvé dans la page https://sealevelrise.brgm.fr/slr/
# Page HTML sauvegardée : html_pages/page_2_Montée_des_eaux.html
# Page HTML sauvegardée : html_pages/page_2_Montée_des_eaux.html
# Page HTML sauvegardée : html_pages/page_2_Montée_des_eaux.html
# Recherche Google effectuée avec : Bassins côtiers
# Page HTML sauvegardée : html_pages/page_2_Bassins_côtiers.html
# Aucun mot-clé trouvé dans la page https://sage-coc.fr/le-territoire
# Page HTML sauvegardée : html_pages/page_2_Bassins_côtiers.html
# Aucun mot-clé trouvé dans la page https://www.appcb.fr/wp-content/uploads/2021/01/exe_guide-du-sage_appcb_dol_web.pdf
# Aucun mot-clé trouvé dans la page https://www.appcb.fr/wp-content/uploads/2021/01/exe_guide-du-sage_appcb_dol_web.pdf
# Recherche Google effectuée avec : Barres de rochers
# Aucun mot-clé trouvé dans la page https://www.noailles.com/58-c-torrefaction-noailles-barres-rochers.html
# Aucun mot-clé trouvé dans la page https://www.noailles.com/296-58-p-barres-rochers-rocher-lait.html
# Recherche Google effectuée avec : Migration anticipée
# Erreur lors de l'accès à la page https://www.psthc.fr/trophee/webbed-ps4/migration-anticipee.htm: 403 Client Error: Forbidden for url: https://www.psthc.fr/trophee/webbed-ps4/migration-anticipee.htm
# Aucun mot-clé trouvé dans la page https://www.lalibre.be/planete/environnement/2024/02/11/la-migration-des-batraciens-debute-de-facon-anticipee-3BMQRHHUBNFVTDRGEVPWGFBSXM/
# Aucun mot-clé trouvé dans la page https://www.tvhconsulting.fr/erp/sap/migration-sap-s4hana-dossier-complet/
# Aucun mot-clé trouvé dans la page https://terres-et-territoires.com/cest-tout-frais/legislatives-2024-quels-programmes-pour-limmigration
# Aucun mot-clé trouvé dans la page https://parc-cotentin-bessin.fr/sites/default/files/2019-05/PNRMCB_DOSSIER_PEDAGOGIQUE_MIGRATION.pdf
# Page HTML sauvegardée : html_pages/page_2_Migration_anticipée.html
# Aucun mot-clé trouvé dans la page https://www.euractiv.fr/section/immigration/news/droit-du-sol-pacte-asile-et-migration-jordan-bardella-precise-le-volet-immigration-du-rn/
# Aucun mot-clé trouvé dans la page https://parti-renaissance.fr/bilan-europeennes/pacte-asile-migration
# Aucun mot-clé trouvé dans la page http://www.bjinformation.com/enen/txt/2015-05/18/content_688246.htm
# Aucun mot-clé trouvé dans la page https://www.radiofrance.fr/franceculture/podcasts/journal-de-7-h/journal-de-7h-du-jeudi-27-juin-2024-9552728
# Recherche Google effectuée avec : Agglomérations
# Page HTML sauvegardée : html_pages/page_2_Agglomérations.html
# Aucun mot-clé trouvé dans la page https://geoconfluences.ens-lyon.fr/glossaire/agglomeration
# Aucun mot-clé trouvé dans la page https://www.larousse.fr/dictionnaires/francais/agglom%C3%A9ration/1635
# Aucun mot-clé trouvé dans la page https://www.vie-publique.fr/fiches/20126-quest-ce-quune-communaute-dagglomeration
# Page HTML sauvegardée : html_pages/page_2_Agglomérations.html
# Page HTML sauvegardée : html_pages/page_2_Agglomérations.html
# Page HTML sauvegardée : html_pages/page_2_Agglomérations.html
# Page HTML sauvegardée : html_pages/page_2_Agglomérations.html
# Page HTML sauvegardée : html_pages/page_2_Agglomérations.html
# Page HTML sauvegardée : html_pages/page_2_Agglomérations.html
# Recherche Google effectuée avec : Erosion côtière
# Erreur lors de l'accès à la page https://www.finistere.gouv.fr/contenu/telechargement/44736/317999/file/20210118_traits_de_co%CC%82te_Finist%C3%A8re.pdf: 410 Client Error: Gone for url: https://www.finistere.gouv.fr/contenu/telechargement/44736/317999/file/20210118_traits_de_co%CC%82te_Finist%C3%A8re.pdf
# Aucun mot-clé trouvé dans la page https://pedagogie.ac-guadeloupe.fr/edd/lerosion_cotiere_quest_ce_que_cest_brgm
# Aucun mot-clé trouvé dans la page https://www.pimpant.com/media/erosion-littorale
# Aucun mot-clé trouvé dans la page http://www.cerema.fr/fr/mots-cles/erosion-cotiere
# Page HTML sauvegardée : html_pages/page_3_Erosion_côtière.html
# Page HTML sauvegardée : html_pages/page_3_Erosion_côtière.html
# Recherche Google effectuée avec : Recul du littoral
# Page HTML sauvegardée : html_pages/page_3_Recul_du_littoral.html
# Aucun mot-clé trouvé dans la page https://www.vie-publique.fr/en-bref/293518-littoral-les-consequences-du-recul-du-trait-de-cote-lhorizon-2100
# Aucun mot-clé trouvé dans la page https://www.francetvinfo.fr/monde/environnement/montee-des-eaux/infographies-monteedeseaux-decouvrez-si-votre-ville-ou-votre-plage-est-grignotee-par-l-erosion-du-littoral_4187797.html
# Aucun mot-clé trouvé dans la page https://www.georisques.gouv.fr/minformer-sur-un-risque/risques-littoraux
# Aucun mot-clé trouvé dans la page http://www.cerema.fr/fr/actualites/evaluation-enjeux-exposes-au-recul-du-trait-cote-court-moyen
# Aucun mot-clé trouvé dans la page https://www.natura-sciences.com/comprendre/recul-du-trait-de-cote-preserver-littoral-francais.html
# Aucun mot-clé trouvé dans la page https://www.mer.gouv.fr/adaptation-des-territoires-aux-evolutions-du-littoral
# Aucun mot-clé trouvé dans la page https://www.geolittoral.developpement-durable.gouv.fr/evaluation-des-enjeux-exposes-au-recul-du-trait-de-a1608.html
# Erreur lors de l'accès à la page https://www.pas-de-calais.gouv.fr/Politiques-publiques/Prevention-des-risques-majeurs/Connaissance-des-risques/Les-risques-naturels/Le-risque-littoral/Le-recul-du-trait-de-cote-lie-a-l-erosion-littorale: 410 Client Error: Gone for url: https://www.pas-de-calais.gouv.fr/Politiques-publiques/Prevention-des-risques-majeurs/Connaissance-des-risques/Les-risques-naturels/Le-risque-littoral/Le-recul-du-trait-de-cote-lie-a-l-erosion-littorale
# Aucun mot-clé trouvé dans la page https://www.banquedesterritoires.fr/blog-des-territoires/le-recul-du-trait-de-cote-un-phenomene-bien-apprehende-par-la-loi-climat-et
# Recherche Google effectuée avec : Plages
# Page HTML sauvegardée : html_pages/page_3_Plages.html
# Page HTML sauvegardée : html_pages/page_3_Plages.html
# Erreur lors de l'accès à la page https://www.labelleplage.fr/: 429 Client Error: Too Many Requests for url: https://www.labelleplage.fr/
# Page HTML sauvegardée : html_pages/page_3_Plages.html
# Page HTML sauvegardée : html_pages/page_3_Plages.html
# Recherche Google effectuée avec : Rivages
# Page HTML sauvegardée : html_pages/page_3_Rivages.html
# Page HTML sauvegardée : html_pages/page_3_Rivages.html
# Page HTML sauvegardée : html_pages/page_3_Rivages.html
# Page HTML sauvegardée : html_pages/page_3_Rivages.html
# Page HTML sauvegardée : html_pages/page_3_Rivages.html
# Page HTML sauvegardée : html_pages/page_3_Rivages.html
# Page HTML sauvegardée : html_pages/page_3_Rivages.html
# Page HTML sauvegardée : html_pages/page_3_Rivages.html
# Page HTML sauvegardée : html_pages/page_3_Rivages.html
# Page HTML sauvegardée : html_pages/page_3_Rivages.html
# Recherche Google effectuée avec : Brises lames
# Aucun mot-clé trouvé dans la page https://www.larousse.fr/dictionnaires/francais/brise-lames/11241
# Aucun mot-clé trouvé dans la page https://www.brise-lames.com/
# Aucun mot-clé trouvé dans la page https://www.brise-lames.com/marques/brise-lames.html
# Aucun mot-clé trouvé dans la page https://www.lycee-brise-lames.fr/
# Aucun mot-clé trouvé dans la page https://regarddecorsaire.com/les-brise-lames/
# Aucun mot-clé trouvé dans la page https://archeorient.hypotheses.org/22210
# Aucun mot-clé trouvé dans la page https://archeorient.hypotheses.org/22210
# Recherche Google effectuée avec : Brise-lames
# Page HTML sauvegardée : html_pages/page_3_Brise-lames.html
# Page HTML sauvegardée : html_pages/page_3_Brise-lames.html
# Page HTML sauvegardée : html_pages/page_3_Brise-lames.html
# Page HTML sauvegardée : html_pages/page_3_Brise-lames.html
# Erreur lors de l'accès à la page https://www.tencategeo.eu/fr/ouvrages/overview/7fTh/Brise-Lames: 403 Client Error: Forbidden for url: https://www.tencategeo.eu/fr/ouvrages/overview/7fTh/Brise-Lames
# Page HTML sauvegardée : html_pages/page_3_Brise-lames.html
# Page HTML sauvegardée : html_pages/page_3_Brise-lames.html
# Page HTML sauvegardée : html_pages/page_3_Brise-lames.html
# Page HTML sauvegardée : html_pages/page_3_Brise-lames.html
# Erreur lors de l'accès à la page https://dictionnaire.lerobert.com/en/definition/brise-lame: 403 Client Error: Forbidden for url: https://dictionnaire.lerobert.com/en/definition/brise-lame
# Recherche Google effectuée avec : Repli stratégique
# Erreur lors de l'accès à la page https://dictionnaire.lerobert.com/definition/repli-strategique: 403 Client Error: Forbidden for url: https://dictionnaire.lerobert.com/definition/repli-strategique
# Erreur lors de l'accès à la page https://dictionnaire.reverso.net/francais-definition/repli+strat%C3%A9gique: 403 Client Error: Forbidden for url: https://dictionnaire.reverso.net/francais-definition/repli+strat%C3%A9gique
# Erreur lors de l'accès à la page https://dictionnaire.lerobert.com/definition/strategie-de-repli: 403 Client Error: Forbidden for url: https://dictionnaire.lerobert.com/definition/strategie-de-repli
# Page HTML sauvegardée : html_pages/page_3_Repli_stratégique.html
# Page HTML sauvegardée : html_pages/page_3_Repli_stratégique.html
# Page HTML sauvegardée : html_pages/page_3_Repli_stratégique.html
# Page HTML sauvegardée : html_pages/page_3_Repli_stratégique.html
# Page HTML sauvegardée : html_pages/page_3_Repli_stratégique.html
# Page HTML sauvegardée : html_pages/page_3_Repli_stratégique.html
# Aucun mot-clé trouvé dans la page https://www.littoral-occitanie.fr/Etat-des-lieux-sur-le-recul-strategique
# Recherche Google effectuée avec : Retrait progressif
# Aucun mot-clé trouvé dans la page https://www.service-public.fr/particuliers/vosdroits/F12842
# Aucun mot-clé trouvé dans la page https://www.lassuranceretraite.fr/portail-info/home/actif/je-souhaite-partir-plus-tot/retraite-progressive.html
# Aucun mot-clé trouvé dans la page https://retraitesdeletat.gouv.fr/actif/lage-de-depart/retraite-progressive
# Aucun mot-clé trouvé dans la page https://www.la-retraite-en-clair.fr/organiser-depart-retraite/preparer-fin-carriere/retraite-progressive
# Aucun mot-clé trouvé dans la page https://www.info-retraite.fr/portail-info/sites/PortailInformationnel/home/mes-droits-a-la-retraite/ma-vie-professionnelle-1/evolution-professionnelle/retraite-progressive.html
# Aucun mot-clé trouvé dans la page https://www.xn--cfdt-retraits-mhb.fr/25-La-retraite-progressive
# Aucun mot-clé trouvé dans la page https://www.retraite.com/dossier-retraite/retraite-progressive/
# Aucun mot-clé trouvé dans la page https://www.previssima.fr/question-pratique/comment-fonctionne-la-retraite-progressive.html
# Aucun mot-clé trouvé dans la page https://www.fonction-publique.gouv.fr/toutes-les-actualites/mise-en-place-de-la-retraite-progressive-dans-la-fonction-publique-compter-du-1er-septembre
# Aucun mot-clé trouvé dans la page https://www.cnracl.retraites.fr/employeur/demande-de-pension/la-retraite-progressive
# Recherche Google effectuée avec : Schémas de Cohérence Territoriale (SCOT)
# Page HTML sauvegardée : html_pages/page_3_Schémas_de_Cohérence_Territoriale_(SCOT).html
# Aucun mot-clé trouvé dans la page https://outil2amenagement.cerema.fr/outils/schema-coherence-territoriale-scot
# Page HTML sauvegardée : html_pages/page_3_Schémas_de_Cohérence_Territoriale_(SCOT).html
# Aucun mot-clé trouvé dans la page https://www.legifrance.gouv.fr/codes/section_lc/LEGITEXT000006074075/LEGISCTA000031210896/
# Page HTML sauvegardée : html_pages/page_3_Schémas_de_Cohérence_Territoriale_(SCOT).html
# Aucun mot-clé trouvé dans la page https://geoconfluences.ens-lyon.fr/glossaire/schema-de-coherence-territoriale-scot
# Aucun mot-clé trouvé dans la page https://www.sportsdenature.gouv.fr/publications/outils-mobilisables-pour-perenniser-acces-lieux-de-pratique/scot-schema-de-coherence-territoriale
# Aucun mot-clé trouvé dans la page https://www.paysprovenceverteverdon.fr/schema-de-coherence-territoriale/quest-ce-quun-schema-de-coherence-territoriale/
# Page HTML sauvegardée : html_pages/page_3_Schémas_de_Cohérence_Territoriale_(SCOT).html
# Page HTML sauvegardée : html_pages/page_3_Schémas_de_Cohérence_Territoriale_(SCOT).html
# Recherche Google effectuée avec : Plans d'aménagement du territoire
# Aucun mot-clé trouvé dans la page https://geoconfluences.ens-lyon.fr/glossaire/amenagement-du-territoire
# Aucun mot-clé trouvé dans la page https://www.ecologie.gouv.fr/politiques-publiques/urbanisme-et-am%C3%A9nagement-du-territoire
# Erreur lors de l'accès à la page https://www.vienne.gouv.fr/Politiques-publiques/Amenagement-du-territoire-construction-et-logement/Amenagement-du-territoire/Planification: 410 Client Error: Gone for url: https://www.vienne.gouv.fr/Politiques-publiques/Amenagement-du-territoire-construction-et-logement/Amenagement-du-territoire/Planification
# Aucun mot-clé trouvé dans la page https://outil2amenagement.cerema.fr/thematiques/strategies-territoriales-et-planification-urbaine
# Aucun mot-clé trouvé dans la page https://fr.wikipedia.org/wiki/Am%C3%A9nagement_du_territoire_en_France
# Erreur lors de l'accès à la page https://www.prefectures-regions.gouv.fr/ile-de-france/Region-et-institutions/L-action-de-l-Etat/Amenagement-du-territoire-transport-et-environnement/Les-grands-projets-d-amenagement: 410 Client Error: Gone for url: https://www.prefectures-regions.gouv.fr/ile-de-france/Region-et-institutions/L-action-de-l-Etat/Amenagement-du-territoire-transport-et-environnement/Les-grands-projets-d-amenagement
# Aucun mot-clé trouvé dans la page https://outil2amenagement.cerema.fr/outils/schema-regional-damenagement-developpement-durable-et-degalite-des-territoires-sraddet
# Erreur lors de l'accès à la page https://www.aude.gouv.fr/Actions-de-l-Etat/Environnement/Plans-et-projets-d-amenagement-susceptibles-d-impacter-l-environnement: 410 Client Error: Gone for url: https://www.aude.gouv.fr/Actions-de-l-Etat/Environnement/Plans-et-projets-d-amenagement-susceptibles-d-impacter-l-environnement
# Aucun mot-clé trouvé dans la page https://amenagement-territoire.public.lu/dam-assets/fr/strategies_territoriales/programme_directeur/detail_progr_direc/Intro.pdf
# Page HTML sauvegardée : html_pages/page_3_Plans_d'aménagement_du_territoire.html
# Recherche Google effectuée avec : DDTM
# Erreur lors de l'accès à la page https://www.nord.gouv.fr/Services-de-l-Etat/Presentation-des-services-de-l-Etat/Services-departementaux-de-l-Etat/Direction-departementale-des-territoires-et-de-la-mer-DDTM: 410 Client Error: Gone for url: https://www.nord.gouv.fr/Services-de-l-Etat/Presentation-des-services-de-l-Etat/Services-departementaux-de-l-Etat/Direction-departementale-des-territoires-et-de-la-mer-DDTM
# Page HTML sauvegardée : html_pages/page_3_DDTM.html
# Erreur lors de l'accès à la page https://www.loire-atlantique.gouv.fr/Services-de-l-Etat/Direction-Departementale-des-Territoires-et-de-la-Mer-DDTM: 410 Client Error: Gone for url: https://www.loire-atlantique.gouv.fr/Services-de-l-Etat/Direction-Departementale-des-Territoires-et-de-la-Mer-DDTM
# Erreur lors de l'accès à la page https://www.seine-maritime.gouv.fr/Services-de-l-Etat/Direction-Departementale-des-Territoires-et-de-la-Mer-de-la-Seine-Maritime-DDTM: 410 Client Error: Gone for url: https://www.seine-maritime.gouv.fr/Services-de-l-Etat/Direction-Departementale-des-Territoires-et-de-la-Mer-de-la-Seine-Maritime-DDTM
# Erreur lors de l'accès à la page https://www.var.gouv.fr/Services-de-l-Etat/DDTM-Agriculture-maritime-environnement-amenagement-et-logement/DDTM-Direction-departementale-des-territoires-et-de-la-mer: 410 Client Error: Gone for url: https://www.var.gouv.fr/Services-de-l-Etat/DDTM-Agriculture-maritime-environnement-amenagement-et-logement/DDTM-Direction-departementale-des-territoires-et-de-la-mer
# Erreur lors de l'accès à la page https://www.gard.gouv.fr/Services-de-l-Etat/Agriculture-environnement-amenagement-et-logement/Direction-Departementale-des-Territoires-et-de-la-Mer-DDTM: 410 Client Error: Gone for url: https://www.gard.gouv.fr/Services-de-l-Etat/Agriculture-environnement-amenagement-et-logement/Direction-Departementale-des-Territoires-et-de-la-Mer-DDTM
# Erreur lors de l'accès à la page https://www.manche.gouv.fr/Services-de-l-Etat/Mer-et-littoral/DDTM: 410 Client Error: Gone for url: https://www.manche.gouv.fr/Services-de-l-Etat/Mer-et-littoral/DDTM
# Erreur lors de l'accès à la page https://www.finistere.gouv.fr/Services-de-l-Etat/Agriculture-environnement-amenagement-et-logement/Direction-departementale-des-territoires-et-de-la-mer-DDTM/La-DDTM: 410 Client Error: Gone for url: https://www.finistere.gouv.fr/Services-de-l-Etat/Agriculture-environnement-amenagement-et-logement/Direction-departementale-des-territoires-et-de-la-mer-DDTM/La-DDTM
# Erreur lors de l'accès à la page https://www.pas-de-calais.gouv.fr/Services-de-l-Etat/Les-Services-de-l-Etat/DDTM: 410 Client Error: Gone for url: https://www.pas-de-calais.gouv.fr/Services-de-l-Etat/Les-Services-de-l-Etat/DDTM
# Erreur lors de l'accès à la page https://www.herault.gouv.fr/Services-de-l-Etat/Agriculture-environnement-amenagement-et-logement/Direction-Departementale-des-Territoires-et-de-la-Mer-de-l-Herault-DDTM-34: 410 Client Error: Gone for url: https://www.herault.gouv.fr/Services-de-l-Etat/Agriculture-environnement-amenagement-et-logement/Direction-Departementale-des-Territoires-et-de-la-Mer-de-l-Herault-DDTM-34
# Recherche Google effectuée avec : Directions Départementales des Territoires et de la Mer
# Aucun mot-clé trouvé dans la page https://lannuaire.service-public.fr/navigation/ddt
# Erreur lors de l'accès à la page https://www.nord.gouv.fr/Services-de-l-Etat/Presentation-des-services-de-l-Etat/Services-departementaux-de-l-Etat/Direction-departementale-des-territoires-et-de-la-mer-DDTM: 410 Client Error: Gone for url: https://www.nord.gouv.fr/Services-de-l-Etat/Presentation-des-services-de-l-Etat/Services-departementaux-de-l-Etat/Direction-departementale-des-territoires-et-de-la-mer-DDTM
# Erreur lors de l'accès à la page https://www.loire-atlantique.gouv.fr/Services-de-l-Etat/Direction-Departementale-des-Territoires-et-de-la-Mer-DDTM: 410 Client Error: Gone for url: https://www.loire-atlantique.gouv.fr/Services-de-l-Etat/Direction-Departementale-des-Territoires-et-de-la-Mer-DDTM
# Erreur lors de l'accès à la page https://www.gironde.gouv.fr/Services-de-l-Etat/Directions-departementales/Direction-Departementale-des-Territoires-et-de-la-Mer-DDTM/Direction-Departementale-des-Territoires-et-de-la-Mer: 410 Client Error: Gone for url: https://www.gironde.gouv.fr/Services-de-l-Etat/Directions-departementales/Direction-Departementale-des-Territoires-et-de-la-Mer-DDTM/Direction-Departementale-des-Territoires-et-de-la-Mer
# Erreur lors de l'accès à la page https://www.ille-et-vilaine.gouv.fr/Services-de-l-Etat/Direction-departementale-des-territoires-et-de-la-mer: 410 Client Error: Gone for url: https://www.ille-et-vilaine.gouv.fr/Services-de-l-Etat/Direction-departementale-des-territoires-et-de-la-mer
# Erreur lors de l'accès à la page https://www.morbihan.gouv.fr/Services-de-l-Etat/Agriculture-environnement-amenagement-et-logement/La-direction-departementale-des-Territoires-et-de-la-Mer-DDTM: 410 Client Error: Gone for url: https://www.morbihan.gouv.fr/Services-de-l-Etat/Agriculture-environnement-amenagement-et-logement/La-direction-departementale-des-Territoires-et-de-la-Mer-DDTM
# Erreur lors de l'accès à la page https://www.charente-maritime.gouv.fr/Services-de-l-Etat/Agriculture-environnement-amenagement-et-logement/Direction-Departementale-des-Territoires-et-de-la-Mer-DDTM: 410 Client Error: Gone for url: https://www.charente-maritime.gouv.fr/Services-de-l-Etat/Agriculture-environnement-amenagement-et-logement/Direction-Departementale-des-Territoires-et-de-la-Mer-DDTM
# Erreur lors de l'accès à la page https://www.finistere.gouv.fr/Services-de-l-Etat/Agriculture-environnement-amenagement-et-logement/Direction-departementale-des-territoires-et-de-la-mer-DDTM/La-DDTM: 410 Client Error: Gone for url: https://www.finistere.gouv.fr/Services-de-l-Etat/Agriculture-environnement-amenagement-et-logement/Direction-departementale-des-territoires-et-de-la-mer-DDTM/La-DDTM
# Erreur lors de l'accès à la page https://www.seine-maritime.gouv.fr/Services-de-l-Etat/Direction-Departementale-des-Territoires-et-de-la-Mer-de-la-Seine-Maritime-DDTM: 410 Client Error: Gone for url: https://www.seine-maritime.gouv.fr/Services-de-l-Etat/Direction-Departementale-des-Territoires-et-de-la-Mer-de-la-Seine-Maritime-DDTM
# Erreur lors de l'accès à la page https://www.pas-de-calais.gouv.fr/Services-de-l-Etat/Les-Services-de-l-Etat/DDTM: 410 Client Error: Gone for url: https://www.pas-de-calais.gouv.fr/Services-de-l-Etat/Les-Services-de-l-Etat/DDTM
# Recherche Google effectuée avec : Perte de plage
# Aucun mot-clé trouvé dans la page https://plages.hypotheses.org/973
# Aucun mot-clé trouvé dans la page https://www.futura-sciences.com/planete/actualites/environnement-plages-vont-disparaitre-ici-2100-79852/
# Erreur lors de l'accès à la page https://www.science-et-vie.com/article-magazine/linquietante-disparition-des-plages: 403 Client Error: Forbidden for url: https://www.science-et-vie.com/article-magazine/linquietante-disparition-des-plages
# Erreur lors de l'accès à la page https://www.lesechos.fr/monde/enjeux-internationaux/climat-la-moitie-des-plages-du-monde-sont-menacees-de-disparition-dici-2100-1182898: 403 Client Error: Forbidden for url: https://www.lesechos.fr/monde/enjeux-internationaux/climat-la-moitie-des-plages-du-monde-sont-menacees-de-disparition-dici-2100-1182898
# Aucun mot-clé trouvé dans la page https://up-magazine.info/en/planete/climat/37330-la-moitie-des-plages-du-monde-menacee-de-disparition/
# Aucun mot-clé trouvé dans la page https://webissimo.developpement-durable.gouv.fr/IMG/pdf/guide_erosion_littoral_cle7a511f.pdf
# Aucun mot-clé trouvé dans la page https://fnepaca.fr/dossiers/sable-et-posidonie-le-difficile-equilibre-des-plages
# Aucun mot-clé trouvé dans la page https://www.francetvinfo.fr/monde/environnement/montee-des-eaux/infographies-monteedeseaux-decouvrez-si-votre-ville-ou-votre-plage-est-grignotee-par-l-erosion-du-littoral_4187797.html
# Aucun mot-clé trouvé dans la page https://www.lemonde.fr/afrique/article/2024/07/23/en-tunisie-des-plages-menacees-par-l-erosion-cotiere_6256190_3212.html
# Aucun mot-clé trouvé dans la page https://lareleveetlapeste.fr/le-changement-climatique-menace-la-martinique-qui-perd-ses-plages-a-vue-doeil/
# Recherche Google effectuée avec : Estrans
# Aucun mot-clé trouvé dans la page https://fr.wikipedia.org/wiki/Estran
# Erreur lors de l'accès à la page https://dictionnaire.lerobert.com/en/definition/estrans: 403 Client Error: Forbidden for url: https://dictionnaire.lerobert.com/en/definition/estrans
# Page HTML sauvegardée : html_pages/page_4_Estrans.html
# Page HTML sauvegardée : html_pages/page_4_Estrans.html
# Page HTML sauvegardée : html_pages/page_4_Estrans.html
# Page HTML sauvegardée : html_pages/page_4_Estrans.html
# Page HTML sauvegardée : html_pages/page_4_Estrans.html
# Page HTML sauvegardée : html_pages/page_4_Estrans.html
# Page HTML sauvegardée : html_pages/page_4_Estrans.html
# Page HTML sauvegardée : html_pages/page_4_Estrans.html
# ...
# Recherche Google effectuée avec : Recomposition spatiale
# Page HTML sauvegardée : html_pages/page_7_Recomposition_spatiale.html
# Aucun mot-clé trouvé dans la page https://geoconfluences.ens-lyon.fr/glossaire/recomposition
# Aucun mot-clé trouvé dans la page https://www.vie-publique.fr/rapport/269454-recomposition-spatiale-des-territoires-littoraux
# Aucun mot-clé trouvé dans la page https://www.cerema.fr/system/files/documents/2022/01/12-dbailly-introduction_tr3.pdf
# Aucun mot-clé trouvé dans la page https://www.vie-publique.fr/files/rapport/pdf/194000684.pdf
# Page HTML sauvegardée : html_pages/page_7_Recomposition_spatiale.html
# Page HTML sauvegardée : html_pages/page_7_Recomposition_spatiale.html
# Erreur lors de l'accès à la page https://pedagogie.ac-clermont.fr/disciplines/histoire-geographie/wp-content/uploads/sites/3/2022/05/Fiche_recomposition_RV.pdf: HTTPSConnectionPool(host='pedagogie.ac-clermont.fr', port=443): Max retries exceeded with url: /disciplines/histoire-geographie/wp-content/uploads/sites/3/2022/05/Fiche_recomposition_RV.pdf (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)')))
# Page HTML sauvegardée : html_pages/page_7_Recomposition_spatiale.html
# Aucun mot-clé trouvé dans la page https://www.pedagogie.ac-nantes.fr/histoire-geographie-citoyennete/enseignement/recompositions-en-geographie-premiere-1284240.kjsp
# Recherche Google effectuée avec : Réorganisation des territoires
# Aucun mot-clé trouvé dans la page https://www.ecologie.gouv.fr/politiques-publiques/loi-portant-nouvelle-organisation-territoriale-republique-notre
# Erreur lors de l'accès à la page https://www.prefectures-regions.gouv.fr/occitanie/Region-et-institutions/Organisation-administrative-de-la-region/Organisation-territoriale-de-l-Etat: 410 Client Error: Gone for url: https://www.prefectures-regions.gouv.fr/occitanie/Region-et-institutions/Organisation-administrative-de-la-region/Organisation-territoriale-de-l-Etat
# Aucun mot-clé trouvé dans la page https://www.vie-publique.fr/loi/20721-loi-notre-loi-du-7-aout-2015-nouvelle-organisation-territoriale-de-la
# Aucun mot-clé trouvé dans la page https://www.modernisation.gouv.fr/actualites/la-reforme-de-lorganisation-territoriale-de-letat
# Aucun mot-clé trouvé dans la page https://www.senat.fr/rap/r08-264-1/r08-264-1_mono.html
# Erreur lors de l'accès à la page https://www.lot.gouv.fr/Services-de-l-Etat/Direction-de-l-emploi-du-travail-des-solidarites-et-de-la-protection-des-populations/La-reforme-de-l-organisation-territoriale-de-l-Etat-de-2021: 410 Client Error: Gone for url: https://www.lot.gouv.fr/Services-de-l-Etat/Direction-de-l-emploi-du-travail-des-solidarites-et-de-la-protection-des-populations/La-reforme-de-l-organisation-territoriale-de-l-Etat-de-2021
# Aucun mot-clé trouvé dans la page https://injep.fr/wp-content/uploads/2019/02/IAS21_reforme-territoriale_BD.pdf
# Aucun mot-clé trouvé dans la page https://www.senat.fr/rap/r08-264-1/r08-264-1.html
# Erreur lors de l'accès à la page https://www.prefectures-regions.gouv.fr/hauts-de-france/Actualites/2e-etape-de-la-reforme-de-l-organisation-territoriale-de-l-Etat-les-DREETS-et-DDETS: 410 Client Error: Gone for url: https://www.prefectures-regions.gouv.fr/hauts-de-france/Actualites/2e-etape-de-la-reforme-de-l-organisation-territoriale-de-l-Etat-les-DREETS-et-DDETS
# Aucun mot-clé trouvé dans la page https://www.lagazettedescommunes.com/themes/reforme-territoriale/
# Recherche Google effectuée avec : Métropole Perpignan Méditerranée
# Aucun mot-clé trouvé dans la page https://perpignanmediterraneemetropole.fr/
# Aucun mot-clé trouvé dans la page https://perpignanmediterraneemetropole.fr/
# Aucun mot-clé trouvé dans la page https://lannuaire.service-public.fr/occitanie/pyrenees-orientales/a970b8c1-9090-488e-9308-7332c4cf83f2
# Aucun mot-clé trouvé dans la page http://www.pmca.marches-publics.info/
# Aucun mot-clé trouvé dans la page https://annuaire-entreprises.data.gouv.fr/entreprise/perpignan-mediterranee-metropole-communaute-urbaine-200027183
# Aucun mot-clé trouvé dans la page https://www.insee.fr/fr/statistiques/2011101?geo=EPCI-200027183
# Recherche Google effectuée avec : Pôle urbain de la côte catalane
# Aucun mot-clé trouvé dans la page https://www.ledepartement66.fr/wp-content/uploads/2020/02/PDH-19-allege.pdf
# Aucun mot-clé trouvé dans la page https://hal.science/hal-03972994/document
# Aucun mot-clé trouvé dans la page https://agence-cohesion-territoires.gouv.fr/sites/default/files/2022-04/crte-76-66-2%20CRTE%20du%20Pays%20Pyr%C3%A9n%C3%A9es%20M%C3%A9diterran%C3%A9e.pdf
# Aucun mot-clé trouvé dans la page https://fr.wikipedia.org/wiki/Barcelone
# Erreur lors de l'accès à la page https://shs.cairn.info/revue-francaise-d-administration-publique-2003-3-page-357?lang=fr: 403 Client Error: Forbidden for url: https://shs.cairn.info/revue-francaise-d-administration-publique-2003-3-page-357?lang=fr
# Aucun mot-clé trouvé dans la page https://www.universalis.fr/encyclopedie/barcelone/3-l-aire-metropolitaine/
# Aucun mot-clé trouvé dans la page https://www.fabula.org/colloques/document640.php
# Aucun mot-clé trouvé dans la page https://www.urbanisme-puca.gouv.fr/IMG/pdf/vde_internet.pdf
# Aucun mot-clé trouvé dans la page https://www.ecocites.logement.gouv.fr/IMG/pdf/07-22barcelona-francais_cle09f517.pdf
# Aucun mot-clé trouvé dans la page https://geoconfluences.ens-lyon.fr/glossaire/pole-urbain
# Recherche Google effectuée avec : Adapt'O
# Aucun mot-clé trouvé dans la page https://www.lifeadapto.eu/
# Page HTML sauvegardée : html_pages/page_7_Adapt'O.html
# Aucun mot-clé trouvé dans la page https://www.truffaut.com/table-pliante-adapt-o.html?srsltid=AfmBOop1Sja9PyplX_bXpvkGa_tVasCTjPAQ2oBUAMmNNr0P_R_iso9C
# Erreur lors de l'accès à la page https://www.mr-bricolage.fr/table-pliante-adapt-o-70-x-45-x-h71-cm-jardipolys.html: 403 Client Error: Forbidden for url: https://www.mr-bricolage.fr/table-pliante-adapt-o-70-x-45-x-h71-cm-jardipolys.html
# Aucun mot-clé trouvé dans la page https://www.toutpourlamaison.fr/51932-table-pliante-bois-adapt-o-3443440023654.html
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 52
#      49                     print(f"Erreur lors de l'accès à la page {url}: {e}")
#      51 # Lancer le processus de scraping
# ---> 52 scrape_webpages(keywords_df)
#
# Cell In[8], line 32, in scrape_webpages(keywords_df)
#      29 for url in search(keyword):
#      30     try:
#      31         # Faire la requête HTTP pour récupérer la page HTML
# ---> 32         response = requests.get(url)
#      33         response.raise_for_status()
#      35         # Analyser le contenu HTML
#
# File c:\Users\betbe\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\betbe\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\betbe\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\betbe\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\betbe\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\betbe\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File c:\Users\betbe\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     464 try:
#     465     # Trigger any extra validation we need to do.
#     466     try:
# --> 467         self._validate_conn(conn)
#     468     except (SocketTimeout, BaseSSLError) as e:
#     469         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\Users\betbe\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1096, in HTTPSConnectionPool._validate_conn(self, conn)
#    1094 # Force connect early to allow us to validate the connection.
#    1095 if conn.is_closed:
# -> 1096     conn.connect()
#    1098 if not conn.is_verified:
#    1099     warnings.warn(
#    1100         (
#    1101             f"Unverified HTTPS request is being made to host '{conn.host}'. "
#    (...)
#    1106         InsecureRequestWarning,
#    1107     )
#
# File c:\Users\betbe\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:642, in HTTPSConnection.connect(self)
#     633 if is_time_off:
#     634     warnings.warn(
#     635         (
#     636             f"System time is way off (before {RECENT_DATE}). This will probably "
#    (...)
#     639         SystemTimeWarning,
#     640     )
# --> 642 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     643     sock=sock,
#     644     cert_reqs=self.cert_reqs,
#     645     ssl_version=self.ssl_version,
#     646     ssl_minimum_version=self.ssl_minimum_version,
#     647     ssl_maximum_version=self.ssl_maximum_version,
#     648     ca_certs=self.ca_certs,
#     649     ca_cert_dir=self.ca_cert_dir,
#     650     ca_cert_data=self.ca_cert_data,
#     651     cert_file=self.cert_file,
#     652     key_file=self.key_file,
#     653     key_password=self.key_password,
#     654     server_hostname=server_hostname,
#     655     ssl_context=self.ssl_context,
#     656     tls_in_tls=tls_in_tls,
#     657     assert_hostname=self.assert_hostname,
#     658     assert_fingerprint=self.assert_fingerprint,
#     659 )
#     660 self.sock = sock_and_verified.socket
#     661 self.is_verified = sock_and_verified.is_verified
#
# File c:\Users\betbe\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:782, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     779     if is_ipaddress(normalized):
#     780         server_hostname = normalized
# --> 782 ssl_sock = ssl_wrap_socket(
#     783     sock=sock,
#     784     keyfile=key_file,
#     785     certfile=cert_file,
#     786     key_password=key_password,
#     787     ca_certs=ca_certs,
#     788     ca_cert_dir=ca_cert_dir,
#     789     ca_cert_data=ca_cert_data,
#     790     server_hostname=server_hostname,
#     791     ssl_context=context,
#     792     tls_in_tls=tls_in_tls,
#     793 )
#     795 try:
#     796     if assert_fingerprint:
#
# File c:\Users\betbe\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\util\ssl_.py:470, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     467 except NotImplementedError:  # Defensive: in CI, we always have set_alpn_protocols
#     468     pass
# --> 470 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     471 return ssl_sock
#
# File c:\Users\betbe\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\util\ssl_.py:514, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     511     SSLTransport._validate_ssl_context_for_tls_in_tls(ssl_context)
#     512     return SSLTransport(sock, ssl_context, server_hostname)
# --> 514 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File c:\Users\betbe\AppData\Local\Programs\Python\Python312\Lib\ssl.py:455, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     449 def wrap_socket(self, sock, server_side=False,
#     450                 do_handshake_on_connect=True,
#     451                 suppress_ragged_eofs=True,
#     452                 server_hostname=None, session=None):
#     453     # SSLSocket class handles server_hostname encoding before it calls
#     454     # ctx._wrap_socket()
# --> 455     return self.sslsocket_class._create(
#     456         sock=sock,
#     457         server_side=server_side,
#     458         do_handshake_on_connect=do_handshake_on_connect,
#     459         suppress_ragged_eofs=suppress_ragged_eofs,
#     460         server_hostname=server_hostname,
#     461         context=self,
#     462         session=session
#     463     )
#
# File c:\Users\betbe\AppData\Local\Programs\Python\Python312\Lib\ssl.py:1046, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1043         if timeout == 0.0:
#    1044             # non-blocking
#    1045             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1046         self.do_handshake()
#    1047 except (OSError, ValueError):
#    1048     self.close()
#
# File c:\Users\betbe\AppData\Local\Programs\Python\Python312\Lib\ssl.py:1321, in SSLSocket.do_handshake(self, block)
#    1319     if timeout == 0.0 and block:
#    1320         self.settimeout(None)
# -> 1321     self._sslobj.do_handshake()
#    1322 finally:
#    1323     self.settimeout(timeout)
#
# KeyboardInterrupt:
